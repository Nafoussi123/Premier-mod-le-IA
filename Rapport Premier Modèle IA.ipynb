# %% [markdown]
# # Rapport Premier Modèle IA

# %% [markdown]
# ### Un Rappel sur la régression linéaire simple, multiple et polynomiale

# %% [markdown]
# la régression linéaire: En statistiques, un modèle de régression linéaire est un modèle qui cherche à établir une relation linéaire entre une variable X et un variable Y. L'idée est de pouvoir faire des prévisions sur Y lorsque X est mesurée.

# %% [markdown]
# La régression multiple: L'analyse par régression linéaire multiple est une des solutions qui existe pour observer la relation qui existe entre une variable quantitative indépendante et n variables quantitatives indépendantes.

# %% [markdown]
# La régression polynomiale est une forme d'analyse de régression dans laquelle la relation entre la variable explicative et la variable expliquée est modélisé comme un polynome

# %% [markdown]
# ### Explication de chaque fonction en présentant l’équation matricielle qui lui correspond
# (par la méthode normale)
# •

# %% [markdown]
# regression lineaire: y=ax+b (a: la pente, b: l'ordonnée à l'origine)

# %% [markdown]
# regression multiple: Y=ax2+bx=c

# %% [markdown]
# ### Présentation des résultats des modèles sous forme de graphiques

# %% [markdown]
# regression lineaire

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# regression multiple

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# regression polynomiale

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation des modèles

# %% [markdown]
# Regression lineaire:
#     on utilise le coeff de détermination
#     Ce coeff varie entre  0 et 1 (c'est le carré du coeff de corrélation linéaire r)

# %% [markdown]
# Regression multiple:
#     on peut utiliser le mean squared error: Le carré moyen des erreurs (MSE pour Mean Square Error ou MCE pour moyenne des carrés des erreurs) : c’est la moyenne arithmétique des carrés des écarts entre prévisions du modèle et observations.

# %% [markdown]
# regression polynomiale: Une évaluation de la linéarité de la relation entre une variable réponse et une variable prédictive x, peut-être réalisée à l’aide de la fonction scatterplot().
